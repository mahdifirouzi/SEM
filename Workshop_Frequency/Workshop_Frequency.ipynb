# %% [markdown]
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;🐍Python Refresher for Sustainable Energy Management Module
# #### &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;🎓Nottingham Trent University
# ______________________________________________________________________________________________________

# %% [markdown]
# ## Frequency Workshop⚡🛢️💨🏭☀️🔌💡

# %% [markdown]
# ## Outline
# - Recent Frequency Incident in December 2023
# - Time to code Aug 2019 Incident
# _______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# ## Recent Frequency Incident in December 2023
# ### Grid Frequency Data Sets

# %%
print("In this Workshop, we'll take a look inside UK Frequency Incidents")

# %% [markdown]
# ### Download UK Frequency Data:
# - Use the
# - https://www.nationalgrideso.com/data-portal/system-frequency-data
# - and download Dec 2023 Frequency data
# - Upload the CSV file into your computer or Google Colab and change the file path based on the file directory

# %%
# Import Pandas Library
import pandas as pd

# %%
# Assuming your CSV file is named 'f 2019 8.csv' may be you have to change it to your google colab path
file_path = 'fnew-2023-12.csv'

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path, sep=',', parse_dates=['dtm'])

# %%
df.head()

# %%
df.tail()

# %%
# Filter out rows where 'f' is zero
non_zero_df = df[df['f'] != 0]

# %%
# Find the row with the minimum non-zero frequency
min_non_zero_row = non_zero_df.loc[non_zero_df['f'].idxmin()]

# %%
print(min_non_zero_row)

# %%
# Extract timestamp and value
min_timestamp = min_non_zero_row['dtm']
min_value = min_non_zero_row['f']

# %%
# Print the result
print("Minimum non-zero frequency timestamp and value:")
print(f"Timestamp: {min_timestamp}")
print(f"Value: {min_value}")

# %% [markdown]
# - Here is the whole code

# %%
# Here is the whole code
# Import Pandas Library
import pandas as pd

# Assuming your CSV file is named 'f 2019 8.csv' may be you have to change it to your google colab path
file_path = 'fnew-2023-12.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path, sep=',', parse_dates=['dtm'])

# Filter out rows where 'f' is zero
non_zero_df = df[df['f'] != 0]

# Find the row with the minimum non-zero frequency
min_non_zero_row = non_zero_df.loc[non_zero_df['f'].idxmin()]

# Extract timestamp and value
min_timestamp = min_non_zero_row['dtm']
min_value = min_non_zero_row['f']

# Print the result
print("Minimum non-zero frequency timestamp and value:")
print(f"Timestamp: {min_timestamp}")
print(f"Value: {min_value}")

# %% [markdown]
# - Let plot The Frequency before and after the incident

# %%
import matplotlib.pyplot as plt
# Plot a line chart from half an hour before to half an hour after the incident
half_hour_before = min_timestamp - pd.Timedelta(minutes=30)
half_hour_after = min_timestamp + pd.Timedelta(minutes=30)

incident_df = df[(df['dtm'] >= half_hour_before) & (df['dtm'] <= half_hour_after)]

plt.figure(figsize=(40, 10))
plt.plot(incident_df['dtm'], incident_df['f'], linestyle='-', color='g')
plt.title('Frequency Around Incident')
plt.xlabel('Timestamp')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Plot a line chart from one minutes before and after the incident
half_hour_before = min_timestamp - pd.Timedelta(seconds=120)
half_hour_after = min_timestamp + pd.Timedelta(seconds=120)

incident_df = df[(df['dtm'] >= half_hour_before) & (df['dtm'] <= half_hour_after)]

plt.figure(figsize=(40, 10))
plt.plot(incident_df['dtm'], incident_df['f'], linestyle='-', color='g')
plt.title('Frequency Around Incident')
plt.xlabel('Timestamp')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________
# ### Let's see What the news says.
# IFA (🇬🇧 - 🇫🇷 Interconnector) tripped over lunch with a loss of **1GW**.
#
# ⚡Frequency fell as low as 49.3Hz in seconds.
#
# 💪So fast acting frequency response services kicked in to get frequency back into National Grid ESO operational limits.
#
# 🔋 Battery assets on the Kraken platform that were contracted for frequency services over this window delivered a total response of 375 MW, making up just under 40% of the volume lost.
#
# 💨 these services are crucial under current conditions of high levels of wind generation and ESO having to manage a system with low levels of inertia.
#
#
# Context:
# - Operational limits = 49.8-50.2Hz
# - Statutory limits = 49.5-50.5Hz
# - Each coloured line = individual battery sites

# %% [markdown]
#   There are other BESS like:
#   https://eelpower.co.uk/what-we-do/

# %% [markdown]
# ![1703270604855.jpg](attachment:b67a959e-3a05-46b7-9e5b-9377c8707d2a.jpg)

# %% [markdown]
# ______________________________________________________________________________________________________
# ### Time⌚to Code💻
# Now it's your turn to practic!
# 1️⃣ Write a code

# %% [markdown]
# ### Download UK Frequency Data:
#
# - Use the  https://www.nationalgrideso.com/data-portal/system-frequency-data
# - and download Aug 2019 Frequency data
# - Find the Minimum non zero Frequency Time-stamp and find relevant news and reports to that specific time
# - What was the incident and how it affect customers and the UK Grid
